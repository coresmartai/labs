# %% [markdown]
# # Environment Check - Part 1
#
# CoreSmart.AI - 17-Week GenAI Developer Program - Prep Week
#
# **Run every cell top to bottom** (play button, or Shift+Enter).
#
# Nothing here is submitted and nothing is graded. This notebook proves the course's lab environment works for you: a real language model will load and generate text, right here in Colab, no API key and no cost.
#
# If Colab warns that this notebook was not authored by Google, that is expected for every course notebook: click **Run anyway**.

# %%
# Cell 1 - set up this machine (takes about a minute; safe to re-run)
# %pip install -q transformers

import sys
print("python  :", sys.version.split()[0])
print("in colab:", "google.colab" in sys.modules)
print("ok - setup done")

# %%
# Cell 2 - load a small model and generate text.
# First run downloads GPT-2 (~500 MB) and takes a minute. That is normal.
import warnings
warnings.filterwarnings("ignore")

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")
result = generator("Once upon a time", max_length=30,
                   num_return_sequences=1)
print(result[0]["generated_text"])

# %% [markdown]
# GPT-2 is an early, tiny model and its output will be rambling nonsense. **That is fine.** The quality is not the check; the fact that a model loaded and ran end to end is the check.
#
# One rule to carry into every later lab: **never paste an API key into a notebook cell.** When a lab needs a key, it will use Colab's Secrets panel (the key icon in the left sidebar) and show you how.

# %%
# Cell 3 - declare victory
print("PART 1 COMPLETE - the lab environment works.")
print("Now do Part 2 on your own machine (see the item page).")
